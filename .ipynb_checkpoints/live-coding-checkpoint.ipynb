# %%
print("Hello")
# Out:
# Hello

# %%
firstName = "Thomas"

print(firstName)
# Out:
# Thomas

# %%
age = 30

print(f"Bonjour {firstName} tu as {age} ans")
# Out:
# Bonjour Thomas tu as 30 ans

# %%
print(f"L'année prochaine tu aura {age + 1} ans")
# Out:
# L'année prochaine tu aura 31 ans

# %%
input("Entrez votre prénom")
# Out:
# Entrez votre prénom John
# 'John'

# %%
number1 = input('Entrez un premier')
number2 = input('Enterz un deuxième nombre')

sum = int(number1) + int(number2)

print(sum)
# Out:
# Entrez un premier 1
# Enterz un deuxième nombre 1
# 2

# %%
# Calcul du ROI d'une campagne
budget = 5000
revenus = 15000

roi = (revenus - budget) / budget * 100
print("Le ROI de la campagne est de", roi, "%")
# Out:
# Le ROI de la campagne est de 200.0 %
